# %% [markdown]
# This is a notebook that reconstructs the electronic wavefunctions from the planewave coefficients computed by the electronic structure code Abinit. According to Bloch's theorem, the electronic wavefunction of a periodic crystal takes the following form
# \begin{equation}
#     \psi_{n\boldsymbol{k}}(\boldsymbol{r}) = e^{i\boldsymbol{k}\cdot\boldsymbol{r}}u_{n\boldsymbol{k}}(\boldsymbol{r}),
# \end{equation}
# i.e. a planewave modulated by a periodic envelop $u_{n\boldsymbol{k}}(\boldsymbol{r}+\boldsymbol{R}) = u_{n\boldsymbol{k}}(\boldsymbol{r})$, where $\boldsymbol{R}$ is any lattice vector. Here, $\boldsymbol{k}$ is the crystal momentum and $n$ is the band index. Abinit is planewave code, meaning the periodic part of the Bloch functions are expanded as planewaves
# \begin{equation}
#     u_{n\boldsymbol{k}} = \frac{1}{\sqrt{\Omega}}\sum_{\boldsymbol{G}}e^{i\boldsymbol{G}\cdot\boldsymbol{r}}C_{n\boldsymbol{k}}(\boldsymbol{G}),
# \end{equation}
# where $\Omega$ is the unit cell volume, $\boldsymbol{G}$ are the reciprocal lattice vectors, and $C_{n\boldsymbol{k}}(\boldsymbol{G})$ are the coefficients computed by Abinit. Putting these two equations together, we get the following expression for the wavefunction
# \begin{equation}
#     \psi_{n\boldsymbol{k}}(\boldsymbol{r})=\frac{1}{\sqrt{\Omega}}\sum_{\boldsymbol{G}}e^{i\boldsymbol{r}\cdot(\boldsymbol{k}+\boldsymbol{G})}C_{n\boldsymbol{k}}(\boldsymbol{G}).
# \end{equation}

# %% [markdown]
# $\mathbf{G}\cdot\mathbf{r}$
# $\boldsymbol{G}$

# %%
# imports 
import numpy as np

from electron_defect_interaction.utils.pw_utils import *
from electron_defect_interaction.utils.get_utils import *
from electron_defect_interaction.analysis.wfk.wfk import * 


import os
os.chdir("/Users/gregou/electron_defect_interaction")

# %%
# Path to the Abinit WFK file for 5x5x1 MP grid graphene unit cell
WFK_551 = "data/graphene/unit_cell/5x5x1/abinit/sp2/graphene_w90_5x5x1o_DS2_WFK.nc"

# Getting necessary ingredients
C_nk, npw = get_C_nk(WFK_551) # planewave coefficients
G_red = get_G(WFK_551) # reciprocal lattice vectors
k_red = get_KPT(WFK_551) # kpoint grid
A, Omega = get_A_volume(WFK_551) # direct primitive lattice vectors and volume of primitive cell

print(G_red.shape)
# Out:
# (25, 6889, 3)

# %%
# Choosing the FFT grid size, rule of thumb, Ni >= 2*Gmax_i+1, where Gmax is the max G-vector of all k-points and i=x,y,z
Gmax = np.array([0, 0, 0], dtype=int)
for ik in range(k_red.shape[0]):
    npw_k = npw[ik]
    Gk = G_red[ik, :npw_k, :]
    Gmax = np.maximum(Gmax, np.max(np.abs(Gk), axis=0))

Nx, Ny, Nz = grid_from_Gmax(Gmax)
print('Nx, Ny, Nz must be larger than: ', Nx, Ny, Nz)
# Out:
# Nx, Ny, Nz must be larger than:  15 15 105

# %%
Nx=500; Ny=500; Nz=105

# %%
# Computing wavefunction on a uniform grid
psi_nk_5x5x1, ngfft = compute_psi_nk(C_nk, npw, G_red, k_red, Omega, Nx=250, Ny=250, Nz=105, complex64=False) # (nband, nkpt, Nx, Ny, Nz) array
print(ngfft)
# Checking normalization
Nx, Ny, Nz = ngfft
# norm = np.sum(np.abs(psi_nk_5x5x1)**2, axis=(2,3,4)) * (Omega/(Nx*Ny*Nz))
# assert np.allclose(norm, 1.0, atol=1e-3), f"Wavefunction not normalized! Norm = {norm}"
# Out:
# Computed  1 out of 25 k-points
# Computed  2 out of 25 k-points
# Computed  3 out of 25 k-points
# Computed  4 out of 25 k-points
# Computed  5 out of 25 k-points
# Computed  6 out of 25 k-points
# Computed  7 out of 25 k-points
# Computed  8 out of 25 k-points
# Computed  9 out of 25 k-points
# Computed  10 out of 25 k-points
# Computed  11 out of 25 k-points
# Computed  12 out of 25 k-points
# Computed  13 out of 25 k-points
# Computed  14 out of 25 k-points
# Computed  15 out of 25 k-points
# Computed  16 out of 25 k-points
# Computed  17 out of 25 k-points
# Computed  18 out of 25 k-points
# Computed  19 out of 25 k-points
# Computed  20 out of 25 k-points
# Computed  21 out of 25 k-points
# Computed  22 out of 25 k-points
# Computed  23 out of 25 k-points
# Computed  24 out of 25 k-points
# Computed  25 out of 25 k-points
# (250, 250, 105)

# %%
# normalization check
N = np.prod(ngfft)
norm = np.sum(np.abs(psi_nk_5x5x1)**2, axis=(2,3,4)) * (Omega/N)
assert np.allclose(norm, 1.0, atol=1e-6), f"Wavefunction not normalized! Norm = {norm}"

# %%
# Let's test on finer kpoint grid
WFK_20x20x1 = "data/graphene/unit_cell/20x20x1/sp2/abinit/graphene_w90_20x20x1o_DS2_WFK.nc"

# Getting necessary ingredients
C_nk, npw = get_C_nk(WFK_20x20x1) # planewave coefficients and number of active planewaves
G_red = get_G(WFK_20x20x1) # reciprocal lattice vectors in reduced coordinates
k_red = get_KPT(WFK_20x20x1) # kpoint grid in reduced coordinates
A, Omega = get_A_volume(WFK_20x20x1) # direct primitive lattice vectors and volume of primitive cell

psi_nk_20x20x1, ngfft = compute_psi_nk(C_nk, npw, G_red, k_red, Omega, Nx=None, Ny=None, Nz=None, complex64=False) # (nband, nkpt, Nx, Ny, Nz) array
# Out:
# Computed  1 out of 400 k-points
# Computed  2 out of 400 k-points
# Computed  3 out of 400 k-points
# Computed  4 out of 400 k-points
# Computed  5 out of 400 k-points
# Computed  6 out of 400 k-points
# Computed  7 out of 400 k-points
# Computed  8 out of 400 k-points
# Computed  9 out of 400 k-points
# Computed  10 out of 400 k-points
# Computed  11 out of 400 k-points
# Computed  12 out of 400 k-points
# Computed  13 out of 400 k-points
# Computed  14 out of 400 k-points
# Computed  15 out of 400 k-points
# Computed  16 out of 400 k-points
# Computed  17 out of 400 k-points
# Computed  18 out of 400 k-points
# Computed  19 out of 400 k-points
# Computed  20 out of 400 k-points
# Computed  21 out of 400 k-points
# Computed  22 out of 400 k-points
# Computed  23 out of 400 k-points
# Computed  24 out of 400 k-points
# Computed  25 out of 400 k-points
# Computed  26 out of 400 k-points
# Computed  27 out of 400 k-points
# Computed  28 out of 400 k-points
# Computed  29 out of 400 k-points
# Computed  30 out of 400 k-points
# Computed  31 out of 400 k-points
# Computed  32 out of 400 k-points
# Computed  33 out of 400 k-points
# Computed  34 out of 400 k-points
# Computed  35 out of 400 k-points
# Computed  36 out of 400 k-points
# Computed  37 out of 400 k-points
# Computed  38 out of 400 k-points
# Computed  39 out of 400 k-points
# Computed  40 out of 400 k-points
# Computed  41 out of 400 k-points
# Computed  42 out of 400 k-points
# Computed  43 out of 400 k-points
# Computed  44 out of 400 k-points
# Computed  45 out of 400 k-points
# Computed  46 out of 400 k-points
# Computed  47 out of 400 k-points
# Computed  48 out of 400 k-points
# Computed  49 out of 400 k-points
# Computed  50 out of 400 k-points
# Computed  51 out of 400 k-points
# Computed  52 out of 400 k-points
# Computed  53 out of 400 k-points
# Computed  54 out of 400 k-points
# Computed  55 out of 400 k-points
# Computed  56 out of 400 k-points
# Computed  57 out of 400 k-points
# Computed  58 out of 400 k-points
# Computed  59 out of 400 k-points
# Computed  60 out of 400 k-points
# Computed  61 out of 400 k-points
# Computed  62 out of 400 k-points
# Computed  63 out of 400 k-points
# Computed  64 out of 400 k-points
# Computed  65 out of 400 k-points
# Computed  66 out of 400 k-points
# Computed  67 out of 400 k-points
# Computed  68 out of 400 k-points
# Computed  69 out of 400 k-points
# Computed  70 out of 400 k-points
# Computed  71 out of 400 k-points
# Computed  72 out of 400 k-points
# Computed  73 out of 400 k-points
# Computed  74 out of 400 k-points
# Computed  75 out of 400 k-points
# Computed  76 out of 400 k-points
# Computed  77 out of 400 k-points
# Computed  78 out of 400 k-points
# Computed  79 out of 400 k-points
# Computed  80 out of 400 k-points
# Computed  81 out of 400 k-points
# Computed  82 out of 400 k-points
# Computed  83 out of 400 k-points
# Computed  84 out of 400 k-points
# Computed  85 out of 400 k-points
# Computed  86 out of 400 k-points
# Computed  87 out of 400 k-points
# Computed  88 out of 400 k-points
# Computed  89 out of 400 k-points
# Computed  90 out of 400 k-points
# Computed  91 out of 400 k-points
# Computed  92 out of 400 k-points
# Computed  93 out of 400 k-points
# Computed  94 out of 400 k-points
# Computed  95 out of 400 k-points
# Computed  96 out of 400 k-points
# Computed  97 out of 400 k-points
# Computed  98 out of 400 k-points
# Computed  99 out of 400 k-points
# Computed  100 out of 400 k-points
# Computed  101 out of 400 k-points
# Computed  102 out of 400 k-points
# Computed  103 out of 400 k-points
# Computed  104 out of 400 k-points
# Computed  105 out of 400 k-points
# Computed  106 out of 400 k-points
# Computed  107 out of 400 k-points
# Computed  108 out of 400 k-points
# Computed  109 out of 400 k-points
# Computed  110 out of 400 k-points
# Computed  111 out of 400 k-points
# Computed  112 out of 400 k-points
# Computed  113 out of 400 k-points
# Computed  114 out of 400 k-points
# Computed  115 out of 400 k-points
# Computed  116 out of 400 k-points
# Computed  117 out of 400 k-points
# Computed  118 out of 400 k-points
# Computed  119 out of 400 k-points
# Computed  120 out of 400 k-points
# Computed  121 out of 400 k-points
# Computed  122 out of 400 k-points
# Computed  123 out of 400 k-points
# Computed  124 out of 400 k-points
# Computed  125 out of 400 k-points
# Computed  126 out of 400 k-points
# Computed  127 out of 400 k-points
# Computed  128 out of 400 k-points
# Computed  129 out of 400 k-points
# Computed  130 out of 400 k-points
# Computed  131 out of 400 k-points
# Computed  132 out of 400 k-points
# Computed  133 out of 400 k-points
# Computed  134 out of 400 k-points
# Computed  135 out of 400 k-points
# Computed  136 out of 400 k-points
# Computed  137 out of 400 k-points
# Computed  138 out of 400 k-points
# Computed  139 out of 400 k-points
# Computed  140 out of 400 k-points
# Computed  141 out of 400 k-points
# Computed  142 out of 400 k-points
# Computed  143 out of 400 k-points
# Computed  144 out of 400 k-points
# Computed  145 out of 400 k-points
# Computed  146 out of 400 k-points
# Computed  147 out of 400 k-points
# Computed  148 out of 400 k-points
# Computed  149 out of 400 k-points
# Computed  150 out of 400 k-points
# Computed  151 out of 400 k-points
# Computed  152 out of 400 k-points
# Computed  153 out of 400 k-points
# Computed  154 out of 400 k-points
# Computed  155 out of 400 k-points
# Computed  156 out of 400 k-points
# Computed  157 out of 400 k-points
# Computed  158 out of 400 k-points
# Computed  159 out of 400 k-points
# Computed  160 out of 400 k-points
# Computed  161 out of 400 k-points
# Computed  162 out of 400 k-points
# Computed  163 out of 400 k-points
# Computed  164 out of 400 k-points
# Computed  165 out of 400 k-points
# Computed  166 out of 400 k-points
# Computed  167 out of 400 k-points
# Computed  168 out of 400 k-points
# Computed  169 out of 400 k-points
# Computed  170 out of 400 k-points
# Computed  171 out of 400 k-points
# Computed  172 out of 400 k-points
# Computed  173 out of 400 k-points
# Computed  174 out of 400 k-points
# Computed  175 out of 400 k-points
# Computed  176 out of 400 k-points
# Computed  177 out of 400 k-points
# Computed  178 out of 400 k-points
# Computed  179 out of 400 k-points
# Computed  180 out of 400 k-points
# Computed  181 out of 400 k-points
# Computed  182 out of 400 k-points
# Computed  183 out of 400 k-points
# Computed  184 out of 400 k-points
# Computed  185 out of 400 k-points
# Computed  186 out of 400 k-points
# Computed  187 out of 400 k-points
# Computed  188 out of 400 k-points
# Computed  189 out of 400 k-points
# Computed  190 out of 400 k-points
# Computed  191 out of 400 k-points
# Computed  192 out of 400 k-points
# Computed  193 out of 400 k-points
# Computed  194 out of 400 k-points
# Computed  195 out of 400 k-points
# Computed  196 out of 400 k-points
# Computed  197 out of 400 k-points
# Computed  198 out of 400 k-points
# Computed  199 out of 400 k-points
# Computed  200 out of 400 k-points
# Computed  201 out of 400 k-points
# Computed  202 out of 400 k-points
# Computed  203 out of 400 k-points
# Computed  204 out of 400 k-points
# Computed  205 out of 400 k-points
# Computed  206 out of 400 k-points
# Computed  207 out of 400 k-points
# Computed  208 out of 400 k-points
# Computed  209 out of 400 k-points
# Computed  210 out of 400 k-points
# Computed  211 out of 400 k-points
# Computed  212 out of 400 k-points
# Computed  213 out of 400 k-points
# Computed  214 out of 400 k-points
# Computed  215 out of 400 k-points
# Computed  216 out of 400 k-points
# Computed  217 out of 400 k-points
# Computed  218 out of 400 k-points
# Computed  219 out of 400 k-points
# Computed  220 out of 400 k-points
# Computed  221 out of 400 k-points
# Computed  222 out of 400 k-points
# Computed  223 out of 400 k-points
# Computed  224 out of 400 k-points
# Computed  225 out of 400 k-points
# Computed  226 out of 400 k-points
# Computed  227 out of 400 k-points
# Computed  228 out of 400 k-points
# Computed  229 out of 400 k-points
# Computed  230 out of 400 k-points
# Computed  231 out of 400 k-points
# Computed  232 out of 400 k-points
# Computed  233 out of 400 k-points
# Computed  234 out of 400 k-points
# Computed  235 out of 400 k-points
# Computed  236 out of 400 k-points
# Computed  237 out of 400 k-points
# Computed  238 out of 400 k-points
# Computed  239 out of 400 k-points
# Computed  240 out of 400 k-points
# Computed  241 out of 400 k-points
# Computed  242 out of 400 k-points
# Computed  243 out of 400 k-points
# Computed  244 out of 400 k-points
# Computed  245 out of 400 k-points
# Computed  246 out of 400 k-points
# Computed  247 out of 400 k-points
# Computed  248 out of 400 k-points
# Computed  249 out of 400 k-points
# Computed  250 out of 400 k-points
# Computed  251 out of 400 k-points
# Computed  252 out of 400 k-points
# Computed  253 out of 400 k-points
# Computed  254 out of 400 k-points
# Computed  255 out of 400 k-points
# Computed  256 out of 400 k-points
# Computed  257 out of 400 k-points
# Computed  258 out of 400 k-points
# Computed  259 out of 400 k-points
# Computed  260 out of 400 k-points
# Computed  261 out of 400 k-points
# Computed  262 out of 400 k-points
# Computed  263 out of 400 k-points
# Computed  264 out of 400 k-points
# Computed  265 out of 400 k-points
# Computed  266 out of 400 k-points
# Computed  267 out of 400 k-points
# Computed  268 out of 400 k-points
# Computed  269 out of 400 k-points
# Computed  270 out of 400 k-points
# Computed  271 out of 400 k-points
# Computed  272 out of 400 k-points
# Computed  273 out of 400 k-points
# Computed  274 out of 400 k-points
# Computed  275 out of 400 k-points
# Computed  276 out of 400 k-points
# Computed  277 out of 400 k-points
# Computed  278 out of 400 k-points
# Computed  279 out of 400 k-points
# Computed  280 out of 400 k-points
# Computed  281 out of 400 k-points
# Computed  282 out of 400 k-points
# Computed  283 out of 400 k-points
# Computed  284 out of 400 k-points
# Computed  285 out of 400 k-points
# Computed  286 out of 400 k-points
# Computed  287 out of 400 k-points
# Computed  288 out of 400 k-points
# Computed  289 out of 400 k-points
# Computed  290 out of 400 k-points
# Computed  291 out of 400 k-points
# Computed  292 out of 400 k-points
# Computed  293 out of 400 k-points
# Computed  294 out of 400 k-points
# Computed  295 out of 400 k-points
# Computed  296 out of 400 k-points
# Computed  297 out of 400 k-points
# Computed  298 out of 400 k-points
# Computed  299 out of 400 k-points
# Computed  300 out of 400 k-points
# Computed  301 out of 400 k-points
# Computed  302 out of 400 k-points
# Computed  303 out of 400 k-points
# Computed  304 out of 400 k-points
# Computed  305 out of 400 k-points
# Computed  306 out of 400 k-points
# Computed  307 out of 400 k-points
# Computed  308 out of 400 k-points
# Computed  309 out of 400 k-points
# Computed  310 out of 400 k-points
# Computed  311 out of 400 k-points
# Computed  312 out of 400 k-points
# Computed  313 out of 400 k-points
# Computed  314 out of 400 k-points
# Computed  315 out of 400 k-points
# Computed  316 out of 400 k-points
# Computed  317 out of 400 k-points
# Computed  318 out of 400 k-points
# Computed  319 out of 400 k-points
# Computed  320 out of 400 k-points
# Computed  321 out of 400 k-points
# Computed  322 out of 400 k-points
# Computed  323 out of 400 k-points
# Computed  324 out of 400 k-points
# Computed  325 out of 400 k-points
# Computed  326 out of 400 k-points
# Computed  327 out of 400 k-points
# Computed  328 out of 400 k-points
# Computed  329 out of 400 k-points
# Computed  330 out of 400 k-points
# Computed  331 out of 400 k-points
# Computed  332 out of 400 k-points
# Computed  333 out of 400 k-points
# Computed  334 out of 400 k-points
# Computed  335 out of 400 k-points
# Computed  336 out of 400 k-points
# Computed  337 out of 400 k-points
# Computed  338 out of 400 k-points
# Computed  339 out of 400 k-points
# Computed  340 out of 400 k-points
# Computed  341 out of 400 k-points
# Computed  342 out of 400 k-points
# Computed  343 out of 400 k-points
# Computed  344 out of 400 k-points
# Computed  345 out of 400 k-points
# Computed  346 out of 400 k-points
# Computed  347 out of 400 k-points
# Computed  348 out of 400 k-points
# Computed  349 out of 400 k-points
# Computed  350 out of 400 k-points
# Computed  351 out of 400 k-points
# Computed  352 out of 400 k-points
# Computed  353 out of 400 k-points
# Computed  354 out of 400 k-points
# Computed  355 out of 400 k-points
# Computed  356 out of 400 k-points
# Computed  357 out of 400 k-points
# Computed  358 out of 400 k-points
# Computed  359 out of 400 k-points
# Computed  360 out of 400 k-points
# Computed  361 out of 400 k-points
# Computed  362 out of 400 k-points
# Computed  363 out of 400 k-points
# Computed  364 out of 400 k-points
# Computed  365 out of 400 k-points
# Computed  366 out of 400 k-points
# Computed  367 out of 400 k-points
# Computed  368 out of 400 k-points
# Computed  369 out of 400 k-points
# Computed  370 out of 400 k-points
# Computed  371 out of 400 k-points
# Computed  372 out of 400 k-points
# Computed  373 out of 400 k-points
# Computed  374 out of 400 k-points
# Computed  375 out of 400 k-points
# Computed  376 out of 400 k-points
# Computed  377 out of 400 k-points
# Computed  378 out of 400 k-points
# Computed  379 out of 400 k-points
# Computed  380 out of 400 k-points
# Computed  381 out of 400 k-points
# Computed  382 out of 400 k-points
# Computed  383 out of 400 k-points
# Computed  384 out of 400 k-points
# Computed  385 out of 400 k-points
# Computed  386 out of 400 k-points
# Computed  387 out of 400 k-points
# Computed  388 out of 400 k-points
# Computed  389 out of 400 k-points
# Computed  390 out of 400 k-points
# Computed  391 out of 400 k-points
# Computed  392 out of 400 k-points
# Computed  393 out of 400 k-points
# Computed  394 out of 400 k-points
# Computed  395 out of 400 k-points
# Computed  396 out of 400 k-points
# Computed  397 out of 400 k-points
# Computed  398 out of 400 k-points
# Computed  399 out of 400 k-points
# Computed  400 out of 400 k-points

# %%
# normalization check
N = np.prod(ngfft)
norm = np.sum(np.abs(psi_nk_20x20x1)**2, axis=(2,3,4)) * (Omega/N)
assert np.allclose(norm, 1.0, atol=1e-6), f"Wavefunction not normalized! Norm = {norm}"
# Out:
# (16, 400, 15, 15, 105)

# %%
n=0
psi_5x5x1 = psi_nk_5x5x1[n, 0, :, :, :]  # pi bands (n=4,5), shape (Nx, Ny, Nz)
psi_20x20x1 = psi_nk_20x20x1[n, 0, :, :, :]  # pi bands (n=4,5), shape (Nx, Ny, Nz)

# Charge density = |psi|^2
rho_5x5x1 = np.abs(psi_5x5x1)**2
rho_20x20x1 = np.abs(psi_20x20x1)**2

# plotting charge density
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.imshow(rho_5x5x1[:, :, 0], cmap='viridis')
plt.colorbar(label='Charge Density')
plt.title('Charge Density (5x5x1 k-point grid)')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.subplot(1, 2, 2)
plt.imshow(rho_20x20x1[:, :, 0], cmap='viridis')
plt.colorbar(label='Charge Density')
plt.title('Charge Density (20x20x1 k-point grid)')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.tight_layout()
plt.show()

# %%
# Plotting a supercell!
import matplotlib.pyplot as plt
#  band and kpoint index
n=0; ik=0; iz=0

psi = psi_nk_5x5x1[n, ik, :, :, iz]  # shape (Nx, Ny)
density = np.abs(psi)**2  # shape (Nx, Ny)

# tile density to make 5x5 supercell
density_5x5 = np.tile(density, (3, 3))  # shape (5*Nx, 5*Ny)

plt.figure(figsize=(12, 5))
plt.imshow(density_5x5, cmap='viridis')
plt.colorbar(label='Charge Density')
plt.title('Charge Density (5x5x1 k-point grid)')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
